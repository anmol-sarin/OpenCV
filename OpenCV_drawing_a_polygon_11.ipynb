# %% [markdown]
# ## Syntax of drawing a polygon
# cv2.polylines(new_img,[points],isClosed=True,color=(0, 255, 0),thickness=4,lineType=cv2.LINE_AA)
#
# ![image.png](attachment:9059a5ac-6b9e-4efb-bb37-17cd521b14a5.png)

# %%
import cv2
import numpy as np

# %%
img = cv2.imread(r'C:\Users\anmol sarin\OneDrive\Desktop\me\opencv\images\img-2.webp')
img_resize = cv2.resize(img , (600,500))
new_img = cv2.polylines(img_resize , [np.array([[180,200],[330,50],[420,200],[420,250],[330,250]],np.int32)],True , (0,255,0),4 , cv2.LINE_AA)
cv2.imshow('image' , new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
