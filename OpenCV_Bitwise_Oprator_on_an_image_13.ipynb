# %%
import cv2
import numpy as np

# %%
img1 = cv2.imread(r'C:\Users\anmol sarin\OneDrive\Desktop\me\opencv\images\image_1.png')
img2 = cv2.imread(r'C:\Users\anmol sarin\OneDrive\Desktop\me\opencv\images\image_2.png')
img1 = cv2.resize(img1,(200,200))
img2 = cv2.resize(img2,(200,200))
new = cv2.bitwise_and(img1,img2)
h = np.hstack((img1,img2,new))
cv2.imshow('image' , h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### output
# ![image.png](attachment:682c789a-842a-4007-9be4-140b68862247.png)

# %%
img1 = cv2.imread(r'C:\Users\anmol sarin\OneDrive\Desktop\me\opencv\images\image_1.png')
img2 = cv2.imread(r'C:\Users\anmol sarin\OneDrive\Desktop\me\opencv\images\image_2.png')
img1 = cv2.resize(img1,(200,200))
img2 = cv2.resize(img2,(200,200))
new = cv2.bitwise_or(img1,img2)
h = np.hstack((img1,img2,new))
cv2.imshow('image' , h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### output
# ![image.png](attachment:6a6797a0-638f-41f4-bdec-a437957c2d64.png)

# %%
img1 = cv2.imread(r'C:\Users\anmol sarin\OneDrive\Desktop\me\opencv\images\image_1.png')
img2 = cv2.imread(r'C:\Users\anmol sarin\OneDrive\Desktop\me\opencv\images\image_2.png')
img1 = cv2.resize(img1,(200,200))
img2 = cv2.resize(img2,(200,200))
new = cv2.bitwise_xor(img1,img2)
h = np.hstack((img1,img2,new))
cv2.imshow('image' , h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### output
# ![image.png](attachment:50a07e3a-11e9-4410-a67a-05cebe59a4f2.png)

# %%
img1 = cv2.imread(r'C:\Users\anmol sarin\OneDrive\Desktop\me\opencv\images\image_1.png')
img2 = cv2.imread(r'C:\Users\anmol sarin\OneDrive\Desktop\me\opencv\images\image_2.png')
img1 = cv2.resize(img1,(200,200))
img2 = cv2.resize(img2,(200,200))
new = cv2.bitwise_not(img1)
new2 = cv2.bitwise_not(img2)
h1 = np.hstack((img1,img2))
h2 = np.hstack((new,new2))
v = np.vstack((h1,h2)) 
cv2.imshow('image' , v)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### output
# ![image.png](attachment:b3e51f49-ac19-4b9c-8632-8361679846bb.png)
